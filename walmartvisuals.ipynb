# %% [markdown]
# ![Slide1.JPG](attachment:d4985c0b-509e-40b7-8461-567bd43dfa64.JPG)

# %% [markdown]
# ![Slide2.JPG](attachment:fc82bb3c-6bd9-4ca9-ba36-f16de9027a4c.JPG)

# %% [markdown]
# ![Slide3.JPG](attachment:79f7f2f9-d2d4-4286-b6e8-f56faa643037.JPG)

# %% [markdown]
# ![Slide4.JPG](attachment:f9b4cc5f-3776-45c2-b2f3-f64ac5db168a.JPG)

# %% [markdown]
# ![Slide5.JPG](attachment:7372d1f2-c326-4e5b-86b3-d383d4cb5a89.JPG)

# %% [markdown]
# ![Slide6.JPG](attachment:475bc16c-f793-4ee0-85ab-abd9f64cad58.JPG)

# %% [markdown]
# ![Slide7.JPG](attachment:ced08c66-93db-41aa-af9e-9ee44bb0de0b.JPG)
